# %% [markdown]
# [Tutorial point - Matplotlib](https://www.tutorialspoint.com/matplotlib/index.htm)
# Else check [official website](https://matplotlib.org/3.3.3/tutorials/index.html)

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
x = np.arange(0, 10, 0.1)
y = np.sin(x)

# %%
plt.xlabel("angle")
plt.ylabel("sine")
plt.title("Sine wave")
plt.plot(x, y)

# %%
x = np.arange(-100, 100, 0.1)
y = x**2

# %%
plt.plot(x, y)

# %%
x = np.linspace(0, 10, 50)
x
# Out:
# array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
#         1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
#         2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
#         3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
#         4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
#         5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
#         6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
#         7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
#         8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
#         9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])

# %%
# PLOT WITH MODIFICATIONS

plt.plot(x, np.sin(x), 'r--')
plt.plot(x, np.cos(x), 'g-')

# %%
# SUBPLOT

# 211 => 50% in height, 100% in weight, 1st half of the height
plt.subplot(211)
plt.plot(range(12))

# creates 2nd sub plot with yellow background
plt.subplot(212, facecolor='y') 
plt.plot(range(12))

# %%
x = np.arange(-20, 20)

# %%
fig, a = plt.subplots(2, 2)

a[0][0].plot(x, x*x)
a[0][0].set_title('Square')

a[0][1].plot(x, x*x*x)
a[0][1].set_title('Cube')

a[1][0].plot(x, np.sin(x))
a[1][0].set_title('Sin')

a[1][1].plot(x, np.cos(x))
a[1][1].set_title('Cos')
a[1][1].grid(True)
